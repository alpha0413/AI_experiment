# %%
pwd
# Out:
# '/home/user_kodai/AI_experiment/nlp rl/nlp'

# %% [markdown]
# uvでパッケージのインストール

# %%
# !python language_model_rnn_train.py
# Out:
# 1 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 50.10801815843582.
# 2 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 39.7946441090107.
# 3 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# ...

# %% [markdown]
# 演習2.7.1
# 現在ローカルで実行しているのですが、inputに不具合が生じてしまうので、ターミナルで実行しています。「私」、「は」、「ここ」を入力した結果、「私」、「は」、「あなた」を入力した結果をそれぞれ下に示します。
#
# ```
# $ uv run language_model_rnn_test.py
# input initial words : 私 は ここ
# 私
# は
# ここ
# に
# 君の
# 探している
# 本
# を
# 落とした
# 。
# ```
#
# ```
# $ uv run language_model_rnn_test.py
# input initial words : 私 は あなた
# 私
# あなた
# の
# 両親
# は
# 揺りかご
# の
# 中
# で
# すぐ
# 眠って
# しまった
# 。
# ```

# %% [markdown]
# 演習2.7.2

# %%
# !python language_model_lstm_train.py
# Out:
# 1 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 50.52987893009186.
# 2 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 41.39125921916962.
# 3 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# ...

# %% [markdown]
# 演習2.7.2
# 現在ローカルで実行しているのですが、inputに不具合が生じてしまうので、ターミナルで実行しています。「私」、「は」、「ここ」を入力した結果、「私」、「は」、「あなた」を入力した結果をそれぞれ下に示します。
#
# ```
# $ uv run language_model_lstm_test.py
# input initial words : 私 は ここ
# 私
# は
# ここ
# で
# 目的地
# に
# ついた
# 。
# ```
#
# ```
# $ uv run language_model_lstm_test.py
# input initial words :  私 は あなた
# 私
# は
# あなた
# が
# よく
# 恐怖映画
# を
# 見る
# 。
# ```

# %% [markdown]
# 演習2.7.3

# %%
# !python language_model_lstm_train.py
# Out:
# 1 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 51.61022995471954.
# 2 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 43.03329910373688.
# 3 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# ...

# %% [markdown]
# 演習2.7.3
# 現在ローカルで実行しているのですが、inputに不具合が生じてしまうので、ターミナルで実行しています。「i like to」を入力した結果を下に示します。
#
# ```
# $ uv run language_model_lstm_test.py
# input initial words : i like to
# i
# like
# to
# bed
# late
# at
# night
# .
# ```

# %% [markdown]
# 演習2.7.4
# translator_model_train.pyのinitでネットワークを定義、encodeやdecodeのメソッドでエンコードやデコードを行っている。

# %%
# !python translator_model_train.py
# Out:
# 1 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 55.50378314113617.
# 2 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 46.44375935745239.
# 3 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# ...

# %% [markdown]
# 演習2.7.5
# 現在ローカルで実行しているのですが、inputに不具合が生じてしまうので、ターミナルで実行しています。「I have a book .」を入力した結果を下に示します。
#
# ```
# $ uv run translator_model_test.py
# input an english sentence : I have a book .
# 私は泳ぐのを楽しんだ。
# ```

# %% [markdown]
# 演習2.7.6
# 現在ローカルで実行しているのですが、inputに不具合が生じてしまうので、ターミナルで実行しています。「I have a book .」を入力した結果を下に示します。
#
# ```
# $ uv run translator_model_test.py
# input an english sentence : I have a book .
# 私はその本を読むべきだった。
# ```
